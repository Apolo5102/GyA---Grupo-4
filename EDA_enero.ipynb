# %% [markdown]
# <a href="https://colab.research.google.com/github/Apolo5102/GyA---Grupo-4/blob/main/EDA_enero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Extraccion de los datos a Data frame

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Duro_last = pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/2025-01/USF2 Duro Last Credit Master.xlsx',
                          sheet_name= 'DURO LAST Credit Master', skiprows= 4, usecols="A:AX")

# %%
FSBP = pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/2025-01/USF2 FSBP Credit Master.xlsx',
                          sheet_name= 'FSBP Credit Master File', skiprows= 4, usecols="A:Z")

# %%
SES = pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/2025-01/USF2 GACO-SES Credit Master.xlsx',
                          sheet_name= 'SES Credit Master', skiprows= 4, usecols="A:U")

# %%
Gaco = pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/2025-01/USF2 GACO-SES Credit Master.xlsx',
                          sheet_name= '22520 Sales Tax Credit GACO', skiprows= 4, usecols="A:T")

# %%
Negativos = pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/2025-01/1 NEGATIVE TAX MASTER FILE - ALL US COMPANIES.xlsx',
                          sheet_name= 'HBE NEGATIVE TAX', skiprows= 6, usecols="A:AJ")
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
Ledger = pd.read_csv('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/LEDGER JANUARY 2025.csv',delimiter= ",")
# Out:
# <ipython-input-8-abd049be21f0>:1: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   Ledger = pd.read_csv('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/LEDGER JANUARY 2025.csv',delimiter= ",")

# %%
zip_county= pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/zip_code_database.xlsx',sheet_name= 'data')

# %%
Duro_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   PERIOD USED                    2482 non-null   object
#  1   EXPIRATION DATE                3073 non-null   datetime64[ns]
#  2   SPECIALS INVOICE DATE          3073 non-null   object
#  3   SPECIALS INV#                  3072 non-null   float64
#  4   ORIGINAL TAX REPORTING PERIOD  3073 non-null   object
#  5   Co                             3073 non-null   int64
#  6   Whs                            3073 non-null   object
#  7   WarehouseDescription           3073 non-null   object
#  8   Warehouse City                 2962 non-null   object
#  9   Whse ST                        2962 non-null   object
#  10  Whse Zip                       2962 non-null   float64
#  11  ORIGINAL InvoiceDate           3073 non-null   datetime64[ns]
# ...

# %%
FSBP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9016 entries, 0 to 9015
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Period Used             8010 non-null   object
#  1   Expiration Date         8871 non-null   object
#  2   Posting Period          9016 non-null   datetime64[ns]
#  3   Ship To Account Number  8998 non-null   float64
#  4   Payer Number            9000 non-null   object
#  5   Account Name            8956 non-null   object
#  6   Invoice                 9012 non-null   object
#  7   Invoice Date            9013 non-null   object
#  8   9-Digit Zip Code        9001 non-null   object
#  9   ZIP                     9016 non-null   object
#  10  GEO                     7824 non-null   object
#  11  State                   9016 non-null   object
#  12  County                  8974 non-null   object
#  13  City                    8960 non-null   object
# ...

# %%
SES.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Period Used            3 non-null      datetime64[ns]
#  1   Expiration Date        10 non-null     datetime64[ns]
#  2   Posting Period         10 non-null     datetime64[ns]
#  3   Tax Type               10 non-null     object
#  4   Voucher                0 non-null      float64
#  5   Desc                   0 non-null      float64
#  6   Invoice #              10 non-null     int64
#  7   Debit                  10 non-null     float64
#  8   Credit                 10 non-null     int64
#  9   Import Amount          10 non-null     float64
#  10  Customer               0 non-null      float64
#  11  Customer Name          10 non-null     object
#  12  Original Invoice #     0 non-null      float64
#  13  Original Invoice Date  10 non-null     datetime64[ns]
# ...

# %%
Gaco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Period Used            257 non-null    object
#  1   Expiration Date        287 non-null    datetime64[ns]
#  2   Posting Period         287 non-null    object
#  3   Tax Type               287 non-null    object
#  4   Voucher                277 non-null    object
#  5   Desc                   1 non-null      object
#  6   Invoice #              287 non-null    object
#  7   Debit                  287 non-null    float64
#  8   Credit                 287 non-null    float64
#  9   Import Amount          287 non-null    float64
#  10  Customer               287 non-null    int64
#  11  Customer Name          287 non-null    object
#  12  Original Invoice #     285 non-null    object
#  13  Original Invoice Date  285 non-null    datetime64[ns]
# ...

# %%
Negativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Data columns (total 36 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Jurisdiction Name (State Only)                        484 non-null    object
#  1   Return Period Used                                    262 non-null    object
#  2   Return Period Posted                                  484 non-null    datetime64[ns]
#  3   Expiration Date - Please extend the formula           484 non-null    object
#  4   Tax Type                                              484 non-null    object
#  5   Data Source                                           484 non-null    object
#  6   Company Name                                          480 non-null    object
#  7   Co Role                                               477 non-null    object
# ...

# %%
zip_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42735 entries, 0 to 42734
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   zip                       42735 non-null  int64
#  1   type                      42735 non-null  object
#  2   decommissioned            42735 non-null  int64
#  3   primary_city              42735 non-null  object
#  4   acceptable_cities         9302 non-null   object
#  5   unacceptable_cities       11673 non-null  object
#  6   state                     42735 non-null  object
#  7   county                    41806 non-null  object
#  8   timezone                  41944 non-null  object
#  9   area_codes                41919 non-null  object
#  10  world_region              333 non-null    object
#  11  country                   42657 non-null  object
#  12  latitude                  42735 non-null  float64
# ...

# %%
Ledger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100654 entries, 0 to 100653
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Journal Id             100654 non-null  int64
#  1   Region                 100654 non-null  object
#  2   Tax Location           4260 non-null    float64
#  3    Tax Level             100654 non-null  object
#  4   Tax Authority          100654 non-null  object
#  5   Tax Type               100654 non-null  object
#  6   Tax Name               100654 non-null  object
#  7   Gross                  100654 non-null  float64
#  8   Exemptions             100654 non-null  float64
#  9   Taxable                100654 non-null  float64
#  10  Rate                   100654 non-null  float64
#  11  Tax                    100654 non-null  float64
#  12  Tax Collected          100654 non-null  float64
#  13  Over(Under) Collected  100654 non-null  float64
# ...

# %% [markdown]
# # Preguntas disparadoras
#
#
#
# *   Cuantos creditos quedan por usar (vacios) y cuanto suman en total?
# *   Estados con la mayor cantidad de creditos por usar?
# *   Identificar el nivel al que se pagan impuestos(estado, condado o ciudad)
# *   Realizar tabla dinamica de Ledger para permitir comparacion automatica con los creditos disponibles

# %%
zip_county.columns
# Out:
# Index(['zip', 'type', 'decommissioned', 'primary_city', 'acceptable_cities',
#        'unacceptable_cities', 'state', 'county', 'timezone', 'area_codes',
#        'world_region', 'country', 'latitude', 'longitude',
#        'irs_estimated_population'],
#       dtype='object')

# %%
zip_county = zip_county[['zip','county']]
zip_county.head()
# Out:
#    zip               county
# 0  501       Suffolk County
# 1  544       Suffolk County
# 2  601   Adjuntas Municipio
# 3  602     Aguada Municipio
# 4  603  Aguadilla Municipio

# %%
zip_county.rename(columns={'zip':'Tax Zip'}, inplace=True)
zip_county.head()
# Out:
# <ipython-input-19-1bb21eacc6d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zip_county.rename(columns={'zip':'Tax Zip'}, inplace=True)
#    Tax Zip               county
# 0      501       Suffolk County
# 1      544       Suffolk County
# 2      601   Adjuntas Municipio
# 3      602     Aguada Municipio
# 4      603  Aguadilla Municipio

# %%
Duro_last.columns
# Out:
# Index(['PERIOD USED', 'EXPIRATION DATE', 'SPECIALS INVOICE DATE',
#        'SPECIALS INV#', 'ORIGINAL TAX REPORTING PERIOD', 'Co', 'Whs',
#        'WarehouseDescription', 'Warehouse City', 'Whse ST', 'Whse Zip',
#        'ORIGINAL InvoiceDate', 'ORIGINAL Invoice', 'ORIGINAL Order',
#        'Customer', 'CustomerName', 'ShipToAddress1', 'ShipToAddress2',
#        'ShipToCity', 'ShipToST', 'ShipToZip', 'Carrier', 'TaxSuffix',
#        'Tax Code', 'Tax Amt', 'Tax %', 'Tax Description', 'Tax Base',
#        'TotalItems', 'ItemTax', 'Freight', 'SpecialCharges',
#        'FreightSpcChrgTax', 'TotalTax', 'TotalInvoice', 'Comment',
#        'CREDIT / DEBIT', 'ORIGINAL TAXABLE STATE', 'ORIGINAL TAXABLE COUNTY',
#        'ORIGINAL TAXABLE CITY', 'STATE RATE', 'COUNTY RATE', 'CITY RATE',
#        'DISTRICT RATE', 'TAXABLE AMOUNT', 'STATE TAX', 'COUNTY TAX',
#        'CITY TAX', 'DISTRICT TAX', 'TOTAL TAX'],
#       dtype='object')

# %%
Duro_last = Duro_last[['PERIOD USED','EXPIRATION DATE','ORIGINAL Invoice','ORIGINAL TAXABLE STATE', 'ORIGINAL TAXABLE COUNTY',
                        'ORIGINAL TAXABLE CITY', 'STATE TAX', 'COUNTY TAX',
                        'CITY TAX', 'TOTAL TAX' ]]

Duro_last.head(5)
# Out:
#   PERIOD USED EXPIRATION DATE  ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 0     2024-03      2026-05-19            674993                ALABAMA
# 1     2024-03      2026-05-19            676994                ALABAMA
# 2     2024-03      2026-05-19            677574                ALABAMA
# 3     2024-03      2026-06-19            678797                ALABAMA
# 4     2024-03      2026-06-19            679529                ALABAMA
#
#   ORIGINAL TAXABLE COUNTY ORIGINAL TAXABLE CITY  STATE TAX  COUNTY TAX  \
# 0                  ETOWAH          RAINBOW CITY    -276.96      -69.24
# 1                  ETOWAH          RAINBOW CITY     -26.02       -6.51
# 2                  ETOWAH          RAINBOW CITY      -9.40       -2.35
# 3                  ETOWAH          RAINBOW CITY      -3.58       -0.90
# 4                  ETOWAH          RAINBOW CITY      -0.24       -0.06
#
#    CITY TAX  TOTAL TAX
# 0   -346.20    -692.40
# 1    -32.53     -65.06
# 2    -11.75     -23.50
# ...

# %%
FSBP.columns
# Out:
# Index(['Period Used', 'Expiration Date', 'Posting Period',
#        'Ship To Account Number', 'Payer Number', 'Account Name', 'Invoice',
#        'Invoice Date', '9-Digit Zip Code', 'ZIP', 'GEO', 'State', 'County',
#        'City', 'District', 'State Tax', 'County Tax', 'City Tax',
#        'District Tax', 'Total Tax', 'Correction Number', 'Correction Date',
#        'Comments / Explanation', 'Tax Zip Code', 'Tax Type Code',
#        'Location #'],
#       dtype='object')

# %%
FSBP = FSBP[['Period Used', 'Expiration Date','Invoice','State', 'County',
       'City', 'State Tax', 'County Tax', 'City Tax', 'Total Tax']]

FSBP.head(5)
# Out:
#            Period Used      Expiration Date   Invoice State   County  \
# 0  2021-11-01 00:00:00  2024-05-19 00:00:00  91196074    TX  EL PASO
# 1  2021-11-01 00:00:00  2024-05-19 00:00:00  91196071    TX  EL PASO
# 2  2021-11-01 00:00:00  2024-05-19 00:00:00  91196064    TX  EL PASO
# 3  2021-11-01 00:00:00  2024-07-19 00:00:00  91397923    IL   MCLEAN
# 4  2021-11-01 00:00:00  2025-09-19 00:00:00  91418120    TX  EL PASO
#
#           City State Tax County Tax City Tax  Total Tax
# 0      EL PASO  -2640.77     -211.3  -633.73   -3485.80
# 1      EL PASO  -1425.91    -114.08  -342.19   -1882.18
# 2      EL PASO   -845.06      -67.6  -202.81   -1115.47
# 3  BLOOMINGTON   -1048.6          0        0   -1048.60
# 4      EL PASO   -627.47    -252.52  -153.04   -1033.03

# %%
SES.columns
# Out:
# Index(['Period Used', 'Expiration Date', 'Posting Period', 'Tax Type',
#        'Voucher', 'Desc', 'Invoice #', 'Debit', 'Credit', 'Import Amount',
#        'Customer ', 'Customer Name', 'Original Invoice #',
#        'Original Invoice Date', 'Address', 'Tax City', 'Tax State', 'Tax Zip',
#        'Tax Zip + 4 GEO', 'Location #', 'Comments'],
#       dtype='object')

# %%
SES = SES[['Period Used', 'Expiration Date','Invoice #', 'Tax State','Tax City','Tax Zip',
            'Tax Zip + 4 GEO', 'Import Amount']]

SES.head(10)
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax City  Tax Zip  \
# 0         NaT      2028-03-22      38067        WA     KENT    98031
# 1         NaT      2028-03-22      38068        WA     KENT    98031
# 2         NaT      2028-03-22      38069        WA     KENT    98031
# 3         NaT      2028-03-22      38070        WA     KENT    98031
# 4         NaT      2028-03-22      38071        WA     KENT    98031
# 5         NaT      2028-03-22      38072        WA     KENT    98031
# 6         NaT      2028-03-22      38073        WA     KENT    98031
# 7  2024-05-31      2028-03-22      38075        WA     KENT    98031
# 8  2024-07-31      2028-03-22      38076        WA     KENT    98031
# 9  2024-07-31      2028-03-22      38432        WA     KENT    98031
#
#    Tax Zip + 4 GEO  Import Amount
# 0             1938       -2408.86
# 1             1938       -4585.41
# 2             1938       -4949.00
# 3             1938       -5252.00
# ...

# %%
Gaco.columns
# Out:
# Index(['Period Used', 'Expiration Date', 'Posting Period', 'Tax Type',
#        'Voucher', 'Desc', 'Invoice #', 'Debit', 'Credit', 'Import Amount',
#        'Customer ', 'Customer Name', 'Original Invoice #',
#        'Original Invoice Date', 'Address', 'Tax City', 'Tax State', 'Tax Zip',
#        'Tax Zip + 4 GEO', 'Location #'],
#       dtype='object')

# %%
Gaco = Gaco[['Period Used', 'Expiration Date','Invoice #', 'Tax State','Tax City','Tax Zip',
              'Tax Zip + 4 GEO','Import Amount']]

Gaco.head(10)
# Out:
#            Period Used Expiration Date Invoice # Tax State         Tax City  \
# 0  2021-11-01 00:00:00      2024-05-27  CR010368        CT          NORWALK
# 1  2021-11-01 00:00:00      2024-03-19  CR010411        FL       FORT MYERS
# 2  2021-11-01 00:00:00      2024-04-19  CR010412        FL       FORT MYERS
# 3  2021-11-01 00:00:00      2024-06-27  CR010349        MA     NORTHBOROUGH
# 4  2021-11-01 00:00:00      2025-06-19  CR010365        MD   SPARROWS POINT
# 5  2021-11-01 00:00:00      2025-06-19  CR010346        MD   SPARROWS POINT
# 6  2021-11-01 00:00:00      2025-06-19  CR010348        MD   SPARROWS POINT
# 7  2021-11-01 00:00:00      2025-07-19  CR010339        MD   SPARROWS POINT
# 8  2021-11-01 00:00:00      2025-06-19  CR010347        NJ      BRIDGEWATER
# 9  2021-11-01 00:00:00      2025-09-19  CR010456        NJ  Cloucester City
#
#    Tax Zip  Tax Zip + 4 GEO  Import Amount
# 0     6851              NaN       -1309.40
# 1    33905              NaN         -98.49
# ...

# %%
Negativos.columns
# Out:
# Index(['Jurisdiction Name (State Only)', 'Return Period Used',
#        'Return Period Posted', 'Expiration Date - Please extend the formula',
#        'Tax Type', 'Data Source', 'Company Name', 'Co Role', 'Doc Curr',
#        'Doc Date - Line', 'Fiscal Date', 'Document Number', 'Line No',
#        'Taxable State', 'Taxable County', 'Taxable City',
#        'Taxable Postal Code', 'Taxable Geo Code\n(+ 4)', 'Total Gross Amount',
#        'Exempt Amount', 'Tax Basis Doc Amount', 'Sum Tax Amount',
#        'State Tax Rate', 'County Tax Rate', 'City Tax Rate',
#        'District Tax Rate', 'Total Tax Rate', 'State Tax Amount',
#        'County Tax Amount', 'City Tax Amount', 'District Tax Amount',
#        'Total Tax Amount', 'Status of Tax - If Not Yet Applied', 'Usage Notes',
#        'OriginalPostingDate - Original Billing Document Date',
#        'OriginalBillingDoc - Original Invoice'],
#       dtype='object')

# %%
Negativos = Negativos[['Return Period Used','Expiration Date - Please extend the formula','Document Number',
                       'Data Source','Taxable State', 'Taxable County', 'Taxable City','State Tax Amount','County Tax Amount', 'City Tax Amount','Total Tax Amount']]

Negativos.head()
# Out:
#     Return Period Used Expiration Date - Please extend the formula  \
# 0  2022-10-31 00:00:00                         2025-03-20 00:00:00
# 1  2022-10-31 00:00:00                         2025-03-20 00:00:00
# 2  2022-10-31 00:00:00                         2025-07-31 00:00:00
# 3  2022-10-31 00:00:00                         2025-07-31 00:00:00
# 4                  NaN                         2026-03-20 00:00:00
#
#              Document Number Data Source Taxable State Taxable County  \
# 0                   91496175        FSBP       Alabama      Lee (RDS)
# 1                   91496645        FSBP       Alabama      Lee (RDS)
# 2    2A571f-1660330739-32463         SES       ALABAMA            NaN
# 3  2A9387-1661875160-32584\n         SES       ALABAMA            NaN
# 4                   91651445        FSBP       ALABAMA        Cullman
#
#     Taxable City  State Tax Amount County Tax Amount City Tax Amount  \
# ...

# %%
#Falta period used
Duro_last.describe().T
# Out:
#                    count                           mean                  min  \
# EXPIRATION DATE     3073  2027-08-22 19:31:57.735112192  2025-05-19 00:00:00
# ORIGINAL Invoice  3073.0                  709184.659941              66693.0
# STATE TAX         3073.0                    -897.945264         -39138.80315
# COUNTY TAX        3073.0                    -106.891709             -5690.13
# CITY TAX          3073.0                    -198.981498         -19685.19685
# TOTAL TAX         3073.0                   -1227.225419             -58824.0
#
#                                   25%                  50%  \
# EXPIRATION DATE   2027-02-19 00:00:00  2027-08-19 00:00:00
# ORIGINAL Invoice             699630.0             725430.0
# STATE TAX                     -895.91              -213.36
# COUNTY TAX                     -45.83                  0.0
# CITY TAX                      -66.936                  0.0
# TOTAL TAX                    -1217.77              -286.94
#
# ...

# %%
Duro_last.describe(include= 'O').T
# Out:
#                         count unique         top freq
# PERIOD USED              2482     11     2024-03  671
# ORIGINAL TAXABLE STATE   3073     43       TEXAS  820
# ORIGINAL TAXABLE COUNTY  3073    406      DALLAS  237
# ORIGINAL TAXABLE CITY    3073    619  CARROLLTON  219

# %%
#Problema de fechas
FSBP.describe().T
# Out:
#             count        mean          std       min     25%     50%  \
# Total Tax  9016.0 -960.607433  1592.004368 -32108.12 -1105.0 -622.78
#
#                 75%      max
# Total Tax -155.0925  9661.68

# %%
FSBP.describe(include = 'object').T
# Out:
#                 count unique                   top  freq
# Period Used      8010     73   2021-11-01 00:00:00   749
# Expiration Date  8871    248   2025-06-19 00:00:00   380
# Invoice          9012   8682              91424608     5
# State            9016     42                    IL  1507
# County           8974    421             BALTIMORE   322
# City             8960    690  UNINCORPORATED AREAS  2419
# State Tax        8896   4850                     0  1268
# County Tax       8559   2316                     0  4337
# City Tax         8538   1718                     0  4924

# %%
SES.describe().T
# Out:
#                 count                 mean                  min  \
# Period Used         3  2024-07-10 16:00:00  2024-05-31 00:00:00
# Expiration Date    10  2028-03-22 00:00:00  2028-03-22 00:00:00
# Invoice #        10.0              38107.3              38067.0
# Tax Zip          10.0              98031.0              98031.0
# Tax Zip + 4 GEO  10.0               1938.0               1938.0
# Import Amount    10.0            -3907.994              -5252.0
#
#                                  25%                  50%  \
# Period Used      2024-06-30 12:00:00  2024-07-31 00:00:00
# Expiration Date  2028-03-22 00:00:00  2028-03-22 00:00:00
# Invoice #                   38069.25              38071.5
# Tax Zip                      98031.0              98031.0
# Tax Zip + 4 GEO               1938.0               1938.0
# Import Amount             -4858.1025              -4314.0
#
#                                  75%                  max          std
# ...

# %%
SES.describe(include = 'object').T
# Out:
#           count unique   top freq
# Tax State    10      1    WA   10
# Tax City     10      1  KENT   10

# %%
Gaco.describe().T
# Out:
#                  count                           mean                  min  \
# Expiration Date    287  2026-05-30 17:18:36.376306688  2023-04-19 00:00:00
# Tax Zip          287.0                    48366.54007               1104.0
# Tax Zip + 4 GEO  267.0                    3842.438202                 16.0
# Import Amount    287.0                   -1678.852578            -37221.59
#
#                                  25%                  50%  \
# Expiration Date  2025-09-07 12:00:00  2026-07-31 00:00:00
# Tax Zip                      28803.0              44139.0
# Tax Zip + 4 GEO               1943.0               3124.0
# Import Amount              -2073.825              -632.44
#
#                                  75%                  max           std
# Expiration Date  2027-04-19 00:00:00  2028-11-22 00:00:00           NaN
# Tax Zip                      75262.0              98926.0  28897.808785
# Tax Zip + 4 GEO               5788.5               9779.0   2428.142789
# ...

# %%
# Falta period used to date
Gaco.describe(include = 'object').T
# Out:
#             count unique                  top freq
# Period Used   257     36  2022-08-31 00:00:00   27
# Invoice #     287    287             CR013680    1
# Tax State     287     32                   FL   49
# Tax City      287    141                CAMAS   15

# %%
Negativos.describe().T
# Out:
#                   count         mean          std      min      25%      50%  \
# State Tax Amount  452.0  -733.419490  1676.175013 -15672.2  -479.47 -425.710
# Total Tax Amount  484.0 -1199.022946  2202.422647 -15672.2 -1396.62 -692.375
#
#                       75%     max
# State Tax Amount -20.4150  2052.0
# Total Tax Amount -72.3925  2394.0

# %%
Negativos.describe(include = 'object').T
# Out:
#                                             count unique                  top  \
# Return Period Used                            262     75  2021-11-01 00:00:00
# Expiration Date - Please extend the formula   484     69  2026-04-20 00:00:00
# Document Number                               482    381             91447730
# Data Source                                   484      6                 FSBP
# Taxable State                                 484     30             COLORADO
# Taxable County                                476     85                 Clay
# Taxable City                                  472     81              Liberty
# County Tax Amount                             451    169                    0
# City Tax Amount                               445    160                    0
#
#                                             freq
# Return Period Used                            61
# Expiration Date - Please extend the formula   57
# ...

# %% [markdown]
# **Se identifica como FSBP tiene la mayor cantidad de formatos incorrectos, teniendo como texto varias fechas y valores de taxes necesarios para el desarrollo del proyecto**

# %%
#Correcion de fechas Duro_Last

Duro_last['PERIOD USED'] = pd.to_datetime(Duro_last['PERIOD USED'],errors= 'coerce')

# %%
Duro_last.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PERIOD USED              2482 non-null   datetime64[ns]
#  1   EXPIRATION DATE          3073 non-null   datetime64[ns]
#  2   ORIGINAL Invoice         3073 non-null   int64
#  3   ORIGINAL TAXABLE STATE   3073 non-null   object
#  4   ORIGINAL TAXABLE COUNTY  3073 non-null   object
#  5   ORIGINAL TAXABLE CITY    3073 non-null   object
#  6   STATE TAX                3073 non-null   float64
#  7   COUNTY TAX               3073 non-null   float64
#  8   CITY TAX                 3073 non-null   float64
#  9   TOTAL TAX                3073 non-null   float64
# dtypes: datetime64[ns](2), float64(4), int64(1), object(3)
# memory usage: 240.2+ KB

# %%
#Correccion de fecha period used para FSBP y valores numericos para los niveles de pago de impuestos

FSBP['Period Used'] = pd.to_datetime(FSBP['Period Used'],errors= 'coerce')
FSBP['Expiration Date'] = pd.to_datetime(FSBP['Expiration Date'],errors= 'coerce')
FSBP['State Tax'] = pd.to_numeric(FSBP['State Tax'],errors= 'coerce')
FSBP['County Tax'] = pd.to_numeric(FSBP['County Tax'],errors= 'coerce')
FSBP['City Tax'] = pd.to_numeric(FSBP['City Tax'],errors= 'coerce')

# %%
FSBP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9016 entries, 0 to 9015
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Period Used      7924 non-null   datetime64[ns]
#  1   Expiration Date  8612 non-null   datetime64[ns]
#  2   Invoice          9012 non-null   object
#  3   State            9016 non-null   object
#  4   County           8974 non-null   object
#  5   City             8960 non-null   object
#  6   State Tax        8803 non-null   float64
#  7   County Tax       8137 non-null   float64
#  8   City Tax         7907 non-null   float64
#  9   Total Tax        9016 non-null   float64
# dtypes: datetime64[ns](2), float64(4), object(4)
# memory usage: 704.5+ KB

# %%
Gaco['Period Used'] = pd.to_datetime(Gaco['Period Used'],errors= 'coerce')

# %%
Gaco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 287 entries, 0 to 286
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Period Used      254 non-null    datetime64[ns]
#  1   Expiration Date  287 non-null    datetime64[ns]
#  2   Invoice #        287 non-null    object
#  3   Tax State        287 non-null    object
#  4   Tax City         287 non-null    object
#  5   Tax Zip          287 non-null    int64
#  6   Tax Zip + 4 GEO  267 non-null    float64
#  7   Import Amount    287 non-null    float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(3)
# memory usage: 18.1+ KB

# %%
Negativos['Return Period Used'] = pd.to_datetime(Negativos['Return Period Used'],errors= 'coerce')
Negativos['Expiration Date - Please extend the formula'] = pd.to_datetime(Negativos['Expiration Date - Please extend the formula'],errors= 'coerce')

# %%
Negativos['City Tax Amount']= pd.to_numeric(Negativos['City Tax Amount'],errors= 'coerce')
Negativos['County Tax Amount']= pd.to_numeric(Negativos['County Tax Amount'],errors= 'coerce')
Negativos['State Tax Amount']= pd.to_numeric(Negativos['State Tax Amount'],errors= 'coerce')

# %%
Negativos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Data columns (total 11 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Return Period Used                           233 non-null    datetime64[ns]
#  1   Expiration Date - Please extend the formula  479 non-null    datetime64[ns]
#  2   Document Number                              482 non-null    object
#  3   Data Source                                  484 non-null    object
#  4   Taxable State                                484 non-null    object
#  5   Taxable County                               476 non-null    object
#  6   Taxable City                                 472 non-null    object
#  7   State Tax Amount                             452 non-null    float64
#  8   County Tax Amount                            440 non-null    float64
# ...

# %% [markdown]
# #SIGLAS ESTADOS USA COMPLETE

# %%
us_states_abbreviations = {
    "Alabama": "AL",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "Whashington DC": "DC",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "Alaska": "AK"
}

# %% [markdown]
# # Duro Last

# %%
Duro_last_copia = Duro_last.copy()

# %%
Duro_last_final = Duro_last[Duro_last['PERIOD USED'].isnull()]
Duro_last_final
# Out:
#      PERIOD USED EXPIRATION DATE  ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2341         NaT      2026-05-19            674255                ALABAMA
# 2342         NaT      2026-05-19            677100                ALABAMA
# 2343         NaT      2026-07-19            688002                ALABAMA
# 2344         NaT      2026-08-19            690039                ALABAMA
# 2345         NaT      2026-08-19            690285                ALABAMA
# ...          ...             ...               ...                    ...
# 3049         NaT      2028-01-19            778096                ALABAMA
# 3057         NaT      2028-10-22            764515                   OHIO
# 3059         NaT      2027-06-19            738274                ALABAMA
# 3060         NaT      2028-10-22            766100                   OHIO
# 3068         NaT      2029-01-19            780081                  TEXAS
#
#      ORIGINAL TAXABLE COUNTY ORIGINAL TAXABLE CITY    STATE TAX   COUNTY TAX  \
# ...

# %%
duplicados_factura_DL = Duro_last_final[Duro_last_final.duplicated()]
duplicados_factura_DL
# Out:
#      PERIOD USED EXPIRATION DATE  ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2450         NaT      2026-11-19             69867               MISSOURI
# 2533         NaT      2026-06-19            680373               NEW YORK
# 2534         NaT      2026-06-19            680376               NEW YORK
# 2535         NaT      2026-06-19            681062               NEW YORK
# 2574         NaT      2026-07-19             68092              TENNESSEE
# 2618         NaT      2027-09-19            694435                  TEXAS
# 2682         NaT      2028-08-19            750869                  TEXAS
# 2683         NaT      2028-08-19            751173                  TEXAS
# 2732         NaT      2028-07-19            747653                  TEXAS
# 2736         NaT      2026-12-19            714244            MISSISSIPPI
# 2748         NaT      2027-03-19            727384            MISSISSIPPI
# 2890         NaT      2027-09-19            756201                FLORIDA
# ...

# %%
conteo_DL = duplicados_factura_DL['ORIGINAL Invoice'].value_counts()
conteo_DL
# Out:
# ORIGINAL Invoice
# 756201    2
# 69867     1
# 680376    1
# 680373    1
# 681062    1
# 68092     1
# 750869    1
# 694435    1
# 751173    1
# 747653    1
# 714244    1
# 727384    1
# Name: count, dtype: int64

# %%
conteo_DL.count()
# Out:
# np.int64(12)

# %%
Duro_last_final = Duro_last_final.drop_duplicates()
Duro_last_final
# Out:
#      PERIOD USED EXPIRATION DATE  ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2341         NaT      2026-05-19            674255                ALABAMA
# 2342         NaT      2026-05-19            677100                ALABAMA
# 2343         NaT      2026-07-19            688002                ALABAMA
# 2344         NaT      2026-08-19            690039                ALABAMA
# 2345         NaT      2026-08-19            690285                ALABAMA
# ...          ...             ...               ...                    ...
# 3049         NaT      2028-01-19            778096                ALABAMA
# 3057         NaT      2028-10-22            764515                   OHIO
# 3059         NaT      2027-06-19            738274                ALABAMA
# 3060         NaT      2028-10-22            766100                   OHIO
# 3068         NaT      2029-01-19            780081                  TEXAS
#
#      ORIGINAL TAXABLE COUNTY ORIGINAL TAXABLE CITY    STATE TAX   COUNTY TAX  \
# ...

# %%
Duro_last_final['ORIGINAL TAXABLE STATE'].value_counts()
# Out:
# ORIGINAL TAXABLE STATE
# TEXAS             152
# MISSISSIPPI        76
# ALABAMA            73
# OKLAHOMA           51
# MISSOURI           46
# ARKANSAS           30
# COLORADO           29
# NEW YORK           23
# TENNESSEE          21
# LOUISIANA          18
# KANSAS             16
# CALIFORNIA          8
# FLORIDA             5
# WYOMING             4
# ARIZONA             4
# NEW MEXICO          4
# OHIO                3
# WASHINGTON          3
# NORTH CAROLINA      3
# MINNESOTA           2
# NEBRASKA            2
# WISCONSIN           2
# NORTH DAKOTA        1
# WEST VIRGINIA       1
# UTAH                1
# Name: count, dtype: int64

# %%
Duro_last_final['ORIGINAL TAXABLE STATE'] = Duro_last_final['ORIGINAL TAXABLE STATE'].str.title().str.strip()
Duro_last_final['ORIGINAL TAXABLE COUNTY'] = Duro_last_final['ORIGINAL TAXABLE COUNTY'].str.title().str.strip()
Duro_last_final['ORIGINAL TAXABLE CITY'] = Duro_last_final['ORIGINAL TAXABLE CITY'].str.title().str.strip()
Duro_last_final
# Out:
# <ipython-input-57-acaed2f459de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duro_last_final['ORIGINAL TAXABLE STATE'] = Duro_last_final['ORIGINAL TAXABLE STATE'].str.title().str.strip()
# <ipython-input-57-acaed2f459de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duro_last_final['ORIGINAL TAXABLE COUNTY'] = Duro_last_final['ORIGINAL TAXABLE COUNTY'].str.title().str.strip()
# <ipython-input-57-acaed2f459de>:3: SettingWithCopyWarning:
# ...

# %%
Duro_last_final['ORIGINAL TAXABLE STATE'] = Duro_last_final['ORIGINAL TAXABLE STATE'].map(us_states_abbreviations)
Duro_last_final
# Out:
# <ipython-input-58-1d836564495c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duro_last_final['ORIGINAL TAXABLE STATE'] = Duro_last_final['ORIGINAL TAXABLE STATE'].map(us_states_abbreviations)
#      PERIOD USED EXPIRATION DATE  ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2341         NaT      2026-05-19            674255                     AL
# 2342         NaT      2026-05-19            677100                     AL
# 2343         NaT      2026-07-19            688002                     AL
# 2344         NaT      2026-08-19            690039                     AL
# 2345         NaT      2026-08-19            690285                     AL
# ...          ...             ...               ...                    ...
# ...

# %%
#crea una nueva columna donde especifiques el nombre del archivo de donde provienen los datos, en este caso, el nombre de la columna será fuente y el valor con lo que vas a rellenar será "DURO_LAst"
Duro_last_final['fuente'] = 'Duro Last'
Duro_last_final
# Out:
# <ipython-input-59-66509971775f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duro_last_final['fuente'] = 'Duro Last'
#      PERIOD USED EXPIRATION DATE  ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2341         NaT      2026-05-19            674255                     AL
# 2342         NaT      2026-05-19            677100                     AL
# 2343         NaT      2026-07-19            688002                     AL
# 2344         NaT      2026-08-19            690039                     AL
# 2345         NaT      2026-08-19            690285                     AL
# ...          ...             ...               ...                    ...
# 3049         NaT      2028-01-19            778096                     AL
# ...

# %%
#convertir formato de la columna ORIGINAL INVOICE a str
Duro_last_final['ORIGINAL Invoice'] = Duro_last_final['ORIGINAL Invoice'].astype(str)
Duro_last_final
# Out:
# <ipython-input-60-de5854beb01a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Duro_last_final['ORIGINAL Invoice'] = Duro_last_final['ORIGINAL Invoice'].astype(str)
#      PERIOD USED EXPIRATION DATE ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2341         NaT      2026-05-19           674255                     AL
# 2342         NaT      2026-05-19           677100                     AL
# 2343         NaT      2026-07-19           688002                     AL
# 2344         NaT      2026-08-19           690039                     AL
# 2345         NaT      2026-08-19           690285                     AL
# ...          ...             ...              ...                    ...
# ...

# %%
Duro_last_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 578 entries, 2341 to 3068
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PERIOD USED              0 non-null      datetime64[ns]
#  1   EXPIRATION DATE          578 non-null    datetime64[ns]
#  2   ORIGINAL Invoice         578 non-null    object
#  3   ORIGINAL TAXABLE STATE   578 non-null    object
#  4   ORIGINAL TAXABLE COUNTY  578 non-null    object
#  5   ORIGINAL TAXABLE CITY    578 non-null    object
#  6   STATE TAX                578 non-null    float64
#  7   COUNTY TAX               578 non-null    float64
#  8   CITY TAX                 578 non-null    float64
#  9   TOTAL TAX                578 non-null    float64
#  10  fuente                   578 non-null    object
# dtypes: datetime64[ns](2), float64(4), object(5)
# memory usage: 54.2+ KB

# %%
Duro_last_final['ORIGINAL Invoice'].value_counts()
# Out:
# ORIGINAL Invoice
# 769615    2
# 707186    2
# 690504    2
# 66856     2
# 754423    2
#          ..
# 698965    1
# 698966    1
# 699202    1
# 704833    1
# 679499    1
# Name: count, Length: 573, dtype: int64

# %%
Duro_last_final.to_csv('Duro_last_final.csv', index=False)

# %%
Duro_last_dimension = Duro_last_final.drop_duplicates(subset=['ORIGINAL Invoice'])
Duro_last_dimension
# Out:
#      PERIOD USED EXPIRATION DATE ORIGINAL Invoice ORIGINAL TAXABLE STATE  \
# 2341         NaT      2026-05-19           674255                     AL
# 2342         NaT      2026-05-19           677100                     AL
# 2343         NaT      2026-07-19           688002                     AL
# 2344         NaT      2026-08-19           690039                     AL
# 2345         NaT      2026-08-19           690285                     AL
# ...          ...             ...              ...                    ...
# 3049         NaT      2028-01-19           778096                     AL
# 3057         NaT      2028-10-22           764515                     OH
# 3059         NaT      2027-06-19           738274                     AL
# 3060         NaT      2028-10-22           766100                     OH
# 3068         NaT      2029-01-19           780081                     TX
#
#      ORIGINAL TAXABLE COUNTY ORIGINAL TAXABLE CITY    STATE TAX   COUNTY TAX  \
# ...

# %%
Duro_last_dimension.to_csv('Duro_last_dimension.csv', index=False)

# %% [markdown]
# # FSBP

# %%
FSBP_copia = FSBP.copy()

# %%
FSBP_final = FSBP[FSBP['Period Used'].isnull()]
FSBP_final
# Out:
#      Period Used Expiration Date   Invoice State     County  \
# 586          NaT      2025-08-19  91569359    CO       WELD
# 851          NaT      2024-06-19  91381448    GA     COFFEE
# 853          NaT      2024-07-19  91395643    GA     COFFEE
# 855          NaT      2024-06-19  91373071    GA     COFFEE
# 856          NaT      2024-06-19  91373070    GA     COFFEE
# ...          ...             ...       ...   ...        ...
# 9001         NaT             NaT  91871483    CO    EL PASO
# 9002         NaT             NaT  91781573    TX  FORT BEND
# 9009         NaT             NaT  91862062    TX    LUBBOCK
# 9013         NaT             NaT  91874959    CO    EL PASO
# 9015         NaT             NaT  91869116    UT  SALT LAKE
#
#                       City  State Tax  County Tax  City Tax  Total Tax
# 586               LONGMONT       0.00        0.00   -264.00    -331.30
# 851   UNINCORPORATED AREAS   -4575.31    -4575.44       NaN   -9150.75
# ...

# %%
duplicados_factura_FSBP = FSBP_final[FSBP_final.duplicated()]
duplicados_factura_FSBP
# Out:
#      Period Used Expiration Date   Invoice State      County         City  \
# 7265         NaT      2025-04-19  91512409    CO     BOULDER   LOUISVILLE
# 7915         NaT      2026-02-19  91638457    CO  BROOMFIELD   BROOMFIELD
# 8046         NaT      2026-12-19  91741741    CO       ADAMS  WESTMINSTER
# 8048         NaT      2026-12-19  91741742    CO       ADAMS  WESTMINSTER
# 8049         NaT      2026-12-19  91741743    CO       ADAMS  WESTMINSTER
# 8057         NaT      2026-12-19  91741164    CO        WELD     LONGMONT
# 8172         NaT      2026-06-19  91668014    CO    ARAPAHOE   CENTENNIAL
# 8710         NaT      2028-09-19  91833871    TX      HOWARD   BIG SPRING
# 8845         NaT      2028-09-19  91833872    TX      HOWARD   BIG SPRING
# 8953         NaT             NaT  91879185    NM    DONA ANA   LAS CRUCES
#
#       State Tax  County Tax  City Tax  Total Tax
# 7265        NaN     -148.53   -550.41    -698.94
# 7915       0.00        0.00   -717.27    -717.27
# ...

# %%
conteo_FS = duplicados_factura_FSBP['Invoice'].value_counts()
conteo_FS
# Out:
# Invoice
# 91512409    1
# 91638457    1
# 91741741    1
# 91741742    1
# 91741743    1
# 91741164    1
# 91668014    1
# 91833871    1
# 91833872    1
# 91879185    1
# Name: count, dtype: int64

# %%
FSBP_final = FSBP_final.drop_duplicates()
FSBP_final
# Out:
#      Period Used Expiration Date   Invoice State     County  \
# 586          NaT      2025-08-19  91569359    CO       WELD
# 851          NaT      2024-06-19  91381448    GA     COFFEE
# 853          NaT      2024-07-19  91395643    GA     COFFEE
# 855          NaT      2024-06-19  91373071    GA     COFFEE
# 856          NaT      2024-06-19  91373070    GA     COFFEE
# ...          ...             ...       ...   ...        ...
# 9001         NaT             NaT  91871483    CO    EL PASO
# 9002         NaT             NaT  91781573    TX  FORT BEND
# 9009         NaT             NaT  91862062    TX    LUBBOCK
# 9013         NaT             NaT  91874959    CO    EL PASO
# 9015         NaT             NaT  91869116    UT  SALT LAKE
#
#                       City  State Tax  County Tax  City Tax  Total Tax
# 586               LONGMONT       0.00        0.00   -264.00    -331.30
# 851   UNINCORPORATED AREAS   -4575.31    -4575.44       NaN   -9150.75
# ...

# %%
conteo_FS.count()
# Out:
# np.int64(10)

# %%
FSBP_final['State'].value_counts()
# Out:
# State
# CO    414
# NY     98
# TX     85
# AZ     81
# UT     76
# TN     68
# WA     40
# IA     39
# KS     34
# MO     28
# SC     22
# WI     19
# VA     14
# NM     13
# MS     13
# MN      7
# NE      6
# GA      5
# NC      4
# CA      4
# AL      3
# FL      3
# AR      3
# OK      2
# ID      1
# Name: count, dtype: int64

# %% [markdown]
# **10 facturas duplicadas**

# %%
FSBP_final['City'] = FSBP_final['City'].str.title().str.strip()
FSBP_final['County'] = FSBP_final['County'].str.title().str.strip()
FSBP_final
# Out:
# <ipython-input-73-6e6756e48bd3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FSBP_final['City'] = FSBP_final['City'].str.title().str.strip()
# <ipython-input-73-6e6756e48bd3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FSBP_final['County'] = FSBP_final['County'].str.title().str.strip()
#      Period Used Expiration Date   Invoice State     County  \
# 586          NaT      2025-08-19  91569359    CO       Weld
# 851          NaT      2024-06-19  91381448    GA     Coffee
# ...

# %%
FSBP_final['fuente'] = 'FSBP'
FSBP_final
# Out:
# <ipython-input-74-b9127edf2de5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FSBP_final['fuente'] = 'FSBP'
#      Period Used Expiration Date   Invoice State     County  \
# 586          NaT      2025-08-19  91569359    CO       Weld
# 851          NaT      2024-06-19  91381448    GA     Coffee
# 853          NaT      2024-07-19  91395643    GA     Coffee
# 855          NaT      2024-06-19  91373071    GA     Coffee
# 856          NaT      2024-06-19  91373070    GA     Coffee
# ...          ...             ...       ...   ...        ...
# 9001         NaT             NaT  91871483    CO    El Paso
# 9002         NaT             NaT  91781573    TX  Fort Bend
# 9009         NaT             NaT  91862062    TX    Lubbock
# ...

# %%
FSBP_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1082 entries, 586 to 9015
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Period Used      0 non-null      datetime64[ns]
#  1   Expiration Date  1001 non-null   datetime64[ns]
#  2   Invoice          1082 non-null   object
#  3   State            1082 non-null   object
#  4   County           1082 non-null   object
#  5   City             1082 non-null   object
#  6   State Tax        994 non-null    float64
#  7   County Tax       1008 non-null   float64
#  8   City Tax         954 non-null    float64
#  9   Total Tax        1082 non-null   float64
#  10  fuente           1082 non-null   object
# dtypes: datetime64[ns](2), float64(4), object(5)
# memory usage: 133.7+ KB

# %%
FSBP_DIMENSION = FSBP_final.drop_duplicates(subset=['Invoice'])

# %%
FSBP_DIMENSION.to_csv('FSBP_DIMENSION.csv', index=False)

# %%
FSBP_final.to_csv('FSBP_final.csv', index=False)

# %% [markdown]
# # Gaco

# %% [markdown]
# **Sin facturas duplicadas**

# %%
Gaco_copia = Gaco.copy()

# %%
Gaco_final = Gaco[Gaco['Period Used'].isnull()]
Gaco_final
# Out:
#     Period Used Expiration Date Invoice # Tax State         Tax City  Tax Zip  \
# 232         NaT      2023-04-19  CR010409        OK          EL RENO    73036
# 233         NaT      2024-04-24  CR010378        KS  SHAWNEE MISSION    66227
# 234         NaT      2024-07-24  CR010363        KS  SHAWNEE MISSION    66227
# 235         NaT      2026-07-31  CR012150        AL         Onetonta    35151
# 236         NaT      2026-07-31  CR012151        AL         Onetonta    35151
# 238         NaT      2026-12-19  CR012427        AR     FORREST CITY    72335
# 239         NaT      2027-04-19  CR012785        AR       PINE BLUFF    71601
# 240         NaT      2027-06-27  CR012893        CA           IRVINE    92602
# 241         NaT      2026-12-19  CR012432        CO           GRANBY    80446
# 242         NaT      2027-03-19  CR012693        CO        STRASBURG    80136
# 243         NaT      2027-03-19  CR012694        CO        STRASBURG    80136
# ...

# %%
Gaco_final['Invoice #'] = Gaco_final['Invoice #'].astype(str)
# Out:
# <ipython-input-81-7ca7a27f7ff6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Gaco_final['Invoice #'] = Gaco_final['Invoice #'].astype(str)

# %%
duplicados_factura_Gaco = Gaco_final[Gaco_final.duplicated()]
duplicados_factura_Gaco
# Out:
# Empty DataFrame
# Columns: [Period Used, Expiration Date, Invoice #, Tax State, Tax City, Tax Zip, Tax Zip + 4 GEO, Import Amount]
# Index: []

# %%
# Realizamos un merge (unión) para añadir los nombres de los condados al DataFrame objetivo
Gaco_final = pd.merge(Gaco_final, zip_county, on='Tax Zip', how='left')

#Quitar palabra County de la columna county
Gaco_final['county'] = Gaco_final['county'].str.replace(' County', '')

# Resultado
Gaco_final
# Out:
#    Period Used Expiration Date Invoice # Tax State         Tax City  Tax Zip  \
# 0          NaT      2023-04-19  CR010409        OK          EL RENO    73036
# 1          NaT      2024-04-24  CR010378        KS  SHAWNEE MISSION    66227
# 2          NaT      2024-07-24  CR010363        KS  SHAWNEE MISSION    66227
# 3          NaT      2026-07-31  CR012150        AL         Onetonta    35151
# 4          NaT      2026-07-31  CR012151        AL         Onetonta    35151
# 5          NaT      2026-12-19  CR012427        AR     FORREST CITY    72335
# 6          NaT      2027-04-19  CR012785        AR       PINE BLUFF    71601
# 7          NaT      2027-06-27  CR012893        CA           IRVINE    92602
# 8          NaT      2026-12-19  CR012432        CO           GRANBY    80446
# 9          NaT      2027-03-19  CR012693        CO        STRASBURG    80136
# 10         NaT      2027-03-19  CR012694        CO        STRASBURG    80136
# ...

# %%
Gaco_final.drop(['Tax Zip','Tax Zip + 4 GEO'], axis=1, inplace=True)
Gaco_final
# Out:
#    Period Used Expiration Date Invoice # Tax State         Tax City  \
# 0          NaT      2023-04-19  CR010409        OK          EL RENO
# 1          NaT      2024-04-24  CR010378        KS  SHAWNEE MISSION
# 2          NaT      2024-07-24  CR010363        KS  SHAWNEE MISSION
# 3          NaT      2026-07-31  CR012150        AL         Onetonta
# 4          NaT      2026-07-31  CR012151        AL         Onetonta
# 5          NaT      2026-12-19  CR012427        AR     FORREST CITY
# 6          NaT      2027-04-19  CR012785        AR       PINE BLUFF
# 7          NaT      2027-06-27  CR012893        CA           IRVINE
# 8          NaT      2026-12-19  CR012432        CO           GRANBY
# 9          NaT      2027-03-19  CR012693        CO        STRASBURG
# 10         NaT      2027-03-19  CR012694        CO        STRASBURG
# 11         NaT      2026-09-22  CR011037        WA            CAMAS
# 12         NaT      2026-09-22  CR011038        WA            CAMAS
# ...

# %%
#Organizar las columnas del dataframe de tal forma que county que entre Tax State y Tax City
Gaco_final.rename(columns={'county':'Tax County'}, inplace=True)
Gaco_final = Gaco_final[['Period Used', 'Expiration Date', 'Invoice #', 'Tax State', 'Tax County', 'Tax City', 'Import Amount']]
Gaco_final
# Out:
#    Period Used Expiration Date Invoice # Tax State   Tax County  \
# 0          NaT      2023-04-19  CR010409        OK     Canadian
# 1          NaT      2024-04-24  CR010378        KS      Johnson
# 2          NaT      2024-07-24  CR010363        KS      Johnson
# 3          NaT      2026-07-31  CR012150        AL    Talladega
# 4          NaT      2026-07-31  CR012151        AL    Talladega
# 5          NaT      2026-12-19  CR012427        AR  St. Francis
# 6          NaT      2027-04-19  CR012785        AR    Jefferson
# 7          NaT      2027-06-27  CR012893        CA       Orange
# 8          NaT      2026-12-19  CR012432        CO        Grand
# 9          NaT      2027-03-19  CR012693        CO        Adams
# 10         NaT      2027-03-19  CR012694        CO        Adams
# 11         NaT      2026-09-22  CR011037        WA        Clark
# 12         NaT      2026-09-22  CR011038        WA        Clark
# 13         NaT      2026-10-22  CR011089        WA        Clark
# ...

# %%
Gaco_final['Tax City'] = Gaco_final['Tax City'].str.title().str.strip()
Gaco_final
# Out:
#    Period Used Expiration Date Invoice # Tax State   Tax County  \
# 0          NaT      2023-04-19  CR010409        OK     Canadian
# 1          NaT      2024-04-24  CR010378        KS      Johnson
# 2          NaT      2024-07-24  CR010363        KS      Johnson
# 3          NaT      2026-07-31  CR012150        AL    Talladega
# 4          NaT      2026-07-31  CR012151        AL    Talladega
# 5          NaT      2026-12-19  CR012427        AR  St. Francis
# 6          NaT      2027-04-19  CR012785        AR    Jefferson
# 7          NaT      2027-06-27  CR012893        CA       Orange
# 8          NaT      2026-12-19  CR012432        CO        Grand
# 9          NaT      2027-03-19  CR012693        CO        Adams
# 10         NaT      2027-03-19  CR012694        CO        Adams
# 11         NaT      2026-09-22  CR011037        WA        Clark
# 12         NaT      2026-09-22  CR011038        WA        Clark
# 13         NaT      2026-10-22  CR011089        WA        Clark
# ...

# %%
Gaco_final['Tax State'].value_counts()
# Out:
# Tax State
# WA    14
# CO     9
# KS     2
# AL     2
# CA     2
# AR     2
# OK     1
# FL     1
# Name: count, dtype: int64

# %%
Gaco_final['fuente'] = 'GACO'
Gaco_final
# Out:
#    Period Used Expiration Date Invoice # Tax State   Tax County  \
# 0          NaT      2023-04-19  CR010409        OK     Canadian
# 1          NaT      2024-04-24  CR010378        KS      Johnson
# 2          NaT      2024-07-24  CR010363        KS      Johnson
# 3          NaT      2026-07-31  CR012150        AL    Talladega
# 4          NaT      2026-07-31  CR012151        AL    Talladega
# 5          NaT      2026-12-19  CR012427        AR  St. Francis
# 6          NaT      2027-04-19  CR012785        AR    Jefferson
# 7          NaT      2027-06-27  CR012893        CA       Orange
# 8          NaT      2026-12-19  CR012432        CO        Grand
# 9          NaT      2027-03-19  CR012693        CO        Adams
# 10         NaT      2027-03-19  CR012694        CO        Adams
# 11         NaT      2026-09-22  CR011037        WA        Clark
# 12         NaT      2026-09-22  CR011038        WA        Clark
# 13         NaT      2026-10-22  CR011089        WA        Clark
# ...

# %%
Gaco_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Period Used      0 non-null      datetime64[ns]
#  1   Expiration Date  33 non-null     datetime64[ns]
#  2   Invoice #        33 non-null     object
#  3   Tax State        33 non-null     object
#  4   Tax County       33 non-null     object
#  5   Tax City         33 non-null     object
#  6   Import Amount    33 non-null     float64
#  7   fuente           33 non-null     object
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 2.2+ KB

# %%
Gaco_dimension = Gaco_final.drop_duplicates(subset=['Invoice #'])

# %%
Gaco_dimension.to_csv('Gaco_dimension.csv', index=False)

# %%
Gaco_final.to_csv('Gaco_final.csv', index=False)

# %% [markdown]
# # SES

# %% [markdown]
# **Sin facturas duplicadas**

# %%
SES_copia = SES.copy()

# %%
SES_final = SES[SES['Period Used'].isnull()]
SES_final
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax City  Tax Zip  \
# 0         NaT      2028-03-22      38067        WA     KENT    98031
# 1         NaT      2028-03-22      38068        WA     KENT    98031
# 2         NaT      2028-03-22      38069        WA     KENT    98031
# 3         NaT      2028-03-22      38070        WA     KENT    98031
# 4         NaT      2028-03-22      38071        WA     KENT    98031
# 5         NaT      2028-03-22      38072        WA     KENT    98031
# 6         NaT      2028-03-22      38073        WA     KENT    98031
#
#    Tax Zip + 4 GEO  Import Amount
# 0             1938       -2408.86
# 1             1938       -4585.41
# 2             1938       -4949.00
# 3             1938       -5252.00
# 4             1938       -2805.45
# 5             1938       -3008.30
# 6             1938       -5151.00

# %%
duplicados_factura_SES = SES_final[SES_final.duplicated()]
duplicados_factura_SES
# Out:
# Empty DataFrame
# Columns: [Period Used, Expiration Date, Invoice #, Tax State, Tax City, Tax Zip, Tax Zip + 4 GEO, Import Amount]
# Index: []

# %%
SES_final['Tax State'].value_counts()
# Out:
# Tax State
# WA    7
# Name: count, dtype: int64

# %%
SES_final = pd.merge(SES_final, zip_county, on='Tax Zip', how='left')

#Quitar palabra County de la columna county
SES_final['county'] = SES_final['county'].str.replace(' County', '')

# Resultado
SES_final
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax City  Tax Zip  \
# 0         NaT      2028-03-22      38067        WA     KENT    98031
# 1         NaT      2028-03-22      38068        WA     KENT    98031
# 2         NaT      2028-03-22      38069        WA     KENT    98031
# 3         NaT      2028-03-22      38070        WA     KENT    98031
# 4         NaT      2028-03-22      38071        WA     KENT    98031
# 5         NaT      2028-03-22      38072        WA     KENT    98031
# 6         NaT      2028-03-22      38073        WA     KENT    98031
#
#    Tax Zip + 4 GEO  Import Amount county
# 0             1938       -2408.86   King
# 1             1938       -4585.41   King
# 2             1938       -4949.00   King
# 3             1938       -5252.00   King
# 4             1938       -2805.45   King
# 5             1938       -3008.30   King
# 6             1938       -5151.00   King

# %%
SES_final.drop(['Tax Zip','Tax Zip + 4 GEO'], axis=1, inplace=True)
SES_final
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax City  Import Amount  \
# 0         NaT      2028-03-22      38067        WA     KENT       -2408.86
# 1         NaT      2028-03-22      38068        WA     KENT       -4585.41
# 2         NaT      2028-03-22      38069        WA     KENT       -4949.00
# 3         NaT      2028-03-22      38070        WA     KENT       -5252.00
# 4         NaT      2028-03-22      38071        WA     KENT       -2805.45
# 5         NaT      2028-03-22      38072        WA     KENT       -3008.30
# 6         NaT      2028-03-22      38073        WA     KENT       -5151.00
#
#   county
# 0   King
# 1   King
# 2   King
# 3   King
# 4   King
# 5   King
# 6   King

# %%
SES_final.rename(columns={'county':'Tax County'}, inplace=True)
SES_final = SES_final[['Period Used', 'Expiration Date', 'Invoice #', 'Tax State', 'Tax County', 'Tax City', 'Import Amount']]
SES_final
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax County Tax City  \
# 0         NaT      2028-03-22      38067        WA       King     KENT
# 1         NaT      2028-03-22      38068        WA       King     KENT
# 2         NaT      2028-03-22      38069        WA       King     KENT
# 3         NaT      2028-03-22      38070        WA       King     KENT
# 4         NaT      2028-03-22      38071        WA       King     KENT
# 5         NaT      2028-03-22      38072        WA       King     KENT
# 6         NaT      2028-03-22      38073        WA       King     KENT
#
#    Import Amount
# 0       -2408.86
# 1       -4585.41
# 2       -4949.00
# 3       -5252.00
# 4       -2805.45
# 5       -3008.30
# 6       -5151.00

# %%
SES_final['Tax City'] = SES_final['Tax City'].str.title().str.strip()
SES_final
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax County Tax City  \
# 0         NaT      2028-03-22      38067        WA       King     Kent
# 1         NaT      2028-03-22      38068        WA       King     Kent
# 2         NaT      2028-03-22      38069        WA       King     Kent
# 3         NaT      2028-03-22      38070        WA       King     Kent
# 4         NaT      2028-03-22      38071        WA       King     Kent
# 5         NaT      2028-03-22      38072        WA       King     Kent
# 6         NaT      2028-03-22      38073        WA       King     Kent
#
#    Import Amount
# 0       -2408.86
# 1       -4585.41
# 2       -4949.00
# 3       -5252.00
# 4       -2805.45
# 5       -3008.30
# 6       -5151.00

# %%
SES_final['fuente'] = 'SES'
SES_final
# Out:
#   Period Used Expiration Date  Invoice # Tax State Tax County Tax City  \
# 0         NaT      2028-03-22      38067        WA       King     Kent
# 1         NaT      2028-03-22      38068        WA       King     Kent
# 2         NaT      2028-03-22      38069        WA       King     Kent
# 3         NaT      2028-03-22      38070        WA       King     Kent
# 4         NaT      2028-03-22      38071        WA       King     Kent
# 5         NaT      2028-03-22      38072        WA       King     Kent
# 6         NaT      2028-03-22      38073        WA       King     Kent
#
#    Import Amount fuente
# 0       -2408.86    SES
# 1       -4585.41    SES
# 2       -4949.00    SES
# 3       -5252.00    SES
# 4       -2805.45    SES
# 5       -3008.30    SES
# 6       -5151.00    SES

# %%
SES_final['Invoice #'] = SES_final['Invoice #'].astype(str)

# %%
SES_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Period Used      0 non-null      datetime64[ns]
#  1   Expiration Date  7 non-null      datetime64[ns]
#  2   Invoice #        7 non-null      object
#  3   Tax State        7 non-null      object
#  4   Tax County       7 non-null      object
#  5   Tax City         7 non-null      object
#  6   Import Amount    7 non-null      float64
#  7   fuente           7 non-null      object
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 580.0+ bytes

# %%
SES_dimension = SES_final.drop_duplicates(subset=['Invoice #'])

# %%
SES_dimension.to_csv('SES_dimension.csv', index=False)

# %%
SES_final.to_csv('SES_final.csv', index=False)

# %% [markdown]
# # Negativos

# %%
Negativos_copia = Negativos.copy()

# %%
Negativos_final = Negativos[Negativos['Return Period Used'].isnull()]
Negativos_final
# Out:
#     Return Period Used Expiration Date - Please extend the formula  \
# 4                  NaT                                  2026-03-20
# 6                  NaT                                  2026-09-20
# 7                  NaT                                  2026-09-20
# 8                  NaT                                  2026-08-20
# 12                 NaT                                  2026-07-20
# ..                 ...                                         ...
# 478                NaT                                  2027-12-20
# 480                NaT                                  2027-12-20
# 481                NaT                                  2028-02-20
# 482                NaT                                  2028-02-20
# 483                NaT                                  2028-02-20
#
#     Document Number Data Source Taxable State Taxable County    Taxable City  \
# 4          91651445        FSBP       ALABAMA        Cullman         Cullman
# ...

# %%
duplicados_factura_Negativos = Negativos_final[Negativos_final.duplicated()]
duplicados_factura_Negativos
# Out:
#     Return Period Used Expiration Date - Please extend the formula  \
# 101                NaT                                  2026-02-20
# 380                NaT                                  2024-09-20
# 381                NaT                                  2024-09-20
# 382                NaT                                  2024-09-20
# 383                NaT                                  2024-09-20
# 384                NaT                                  2024-09-20
# 405                NaT                                  2026-01-20
#
#     Document Number Data Source Taxable State Taxable County  Taxable City  \
# 101        91655225        FSBP      COLORADO     BROOMFIELD    BROOMFIELD
# 380      1600701979        FSBP      New York          Essex   Lake Placid
# 381      1600701979        FSBP      New York          Essex   Lake Placid
# 382      1600701979        FSBP      New York          Essex   Lake Placid
# ...

# %%
conteo_NN = duplicados_factura_Negativos['Document Number'].value_counts()
conteo_NN
# Out:
# Document Number
# 1600701979    5
# 91655225      1
# 91630240      1
# Name: count, dtype: int64

# %%
conteo_NN.count()
# Out:
# np.int64(3)

# %%
Negativos_final = Negativos_final.drop_duplicates()
Negativos_final
# Out:
#     Return Period Used Expiration Date - Please extend the formula  \
# 4                  NaT                                  2026-03-20
# 6                  NaT                                  2026-09-20
# 7                  NaT                                  2026-09-20
# 8                  NaT                                  2026-08-20
# 12                 NaT                                  2026-07-20
# ..                 ...                                         ...
# 478                NaT                                  2027-12-20
# 480                NaT                                  2027-12-20
# 481                NaT                                  2028-02-20
# 482                NaT                                  2028-02-20
# 483                NaT                                  2028-02-20
#
#     Document Number Data Source Taxable State Taxable County    Taxable City  \
# 4          91651445        FSBP       ALABAMA        Cullman         Cullman
# ...

# %%
Negativos_final['Data Source'].value_counts()
# Out:
# Data Source
# FSBP         208
# Duro Last     20
# GACO          14
# DURO LAST      1
# DURO           1
# Name: count, dtype: int64

# %%
Negativos_final['Data Source'] = Negativos_final['Data Source'].replace('DURO','Duro Last')
Negativos_final['Data Source'] = Negativos_final['Data Source'].str.title().str.strip()
# Out:
# <ipython-input-114-4bcd54ee7957>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Data Source'] = Negativos_final['Data Source'].replace('DURO','Duro Last')
# <ipython-input-114-4bcd54ee7957>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Data Source'] = Negativos_final['Data Source'].str.title().str.strip()

# %%
Negativos_final['Taxable State'] = Negativos_final['Taxable State'].str.title().str.strip()
# Out:
# <ipython-input-115-d9099162ffed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Taxable State'] = Negativos_final['Taxable State'].str.title().str.strip()

# %%
estados_fuente = Negativos_final.groupby(['Data Source', 'Taxable State']).size().reset_index(name='Cantidad')
estados_fuente
# Out:
#    Data Source Taxable State  Cantidad
# 0    Duro Last       Alabama        10
# 1    Duro Last      Colorado         8
# 2    Duro Last       Florida         1
# 3    Duro Last      Missouri         1
# 4    Duro Last      New York         1
# 5    Duro Last       Vermont         1
# 6         Fsbp       Alabama         1
# 7         Fsbp       Arizona        10
# 8         Fsbp    California         1
# 9         Fsbp      Colorado       121
# 10        Fsbp        Kansas         9
# 11        Fsbp      Missouri        35
# 12        Fsbp      Nebraska         2
# 13        Fsbp    New Mexico         1
# 14        Fsbp      New York         7
# 15        Fsbp     Tennessee        14
# 16        Fsbp          Utah         3
# 17        Fsbp    Washington         4
# 18        Gaco       Alabama         3
# 19        Gaco      Colorado         2
# 20        Gaco       Florida         1
# 21        Gaco     Minnesota         1
# 22        Gaco      Missouri         1
# ...

# %%
Negativos_final['Document Number']=Negativos_final['Document Number'].astype(str)
# Out:
# <ipython-input-117-ee7d4005df5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Document Number']=Negativos_final['Document Number'].astype(str)

# %%
Negativos_final['Taxable State'] = Negativos_final['Taxable State'].map(us_states_abbreviations)
Negativos_final
# Out:
# <ipython-input-118-ed5d78cefec2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Taxable State'] = Negativos_final['Taxable State'].map(us_states_abbreviations)
#     Return Period Used Expiration Date - Please extend the formula  \
# 4                  NaT                                  2026-03-20
# 6                  NaT                                  2026-09-20
# 7                  NaT                                  2026-09-20
# 8                  NaT                                  2026-08-20
# 12                 NaT                                  2026-07-20
# ..                 ...                                         ...
# 478                NaT                                  2027-12-20
# ...

# %%
Negativos_final['Taxable County'] = Negativos_final['Taxable County'].str.title().str.strip()
Negativos_final['Taxable City'] = Negativos_final['Taxable City'].str.title().str.strip()
Negativos_final
# Out:
# <ipython-input-119-d45dfcc6a5d2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Taxable County'] = Negativos_final['Taxable County'].str.title().str.strip()
# <ipython-input-119-d45dfcc6a5d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['Taxable City'] = Negativos_final['Taxable City'].str.title().str.strip()
#     Return Period Used Expiration Date - Please extend the formula  \
# 4                  NaT                                  2026-03-20
# ...

# %%
Negativos_final['fuente'] = 'NEGATIVES'
Negativos_final
# Out:
# <ipython-input-120-3117283dc6df>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Negativos_final['fuente'] = 'NEGATIVES'
#     Return Period Used Expiration Date - Please extend the formula  \
# 4                  NaT                                  2026-03-20
# 6                  NaT                                  2026-09-20
# 7                  NaT                                  2026-09-20
# 8                  NaT                                  2026-08-20
# 12                 NaT                                  2026-07-20
# ..                 ...                                         ...
# 478                NaT                                  2027-12-20
# 480                NaT                                  2027-12-20
# ...

# %%
Negativos_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 244 entries, 4 to 483
# Data columns (total 12 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Return Period Used                           0 non-null      datetime64[ns]
#  1   Expiration Date - Please extend the formula  239 non-null    datetime64[ns]
#  2   Document Number                              244 non-null    object
#  3   Data Source                                  244 non-null    object
#  4   Taxable State                                244 non-null    object
#  5   Taxable County                               241 non-null    object
#  6   Taxable City                                 239 non-null    object
#  7   State Tax Amount                             244 non-null    float64
#  8   County Tax Amount                            234 non-null    float64
# ...

# %%
Negativos_dimension = Negativos_final.drop_duplicates(subset=['Document Number'])

# %%
Negativos_dimension.to_csv('Negativos_dimension.csv', index=False)

# %%
Negativos_final.to_csv('Negativos_final.csv', index=False)

# %% [markdown]
# #O2C REVIEW LEVEL

# %%
#IMPORTAR ARCHIVO DE DRIVE solo las 2 primeras columnas
O2C_REVIEW_LEVEL = pd.read_excel('/content/drive/MyDrive/Shareddrives/gestion &almacenamiento/FSBP - O2C Review Level (Autosaved) (1).xlsx'
,skiprows= 1, usecols="A:B")
O2C_REVIEW_LEVEL
# Out:
#              State O2C Review Level
# 0          Alabama             City
# 1          Arizona             City
# 2         Arkansas           County
# 3       California             City
# 4         Colorado             City
# 5      Connecticut            State
# 6          Florida           County
# 7          Georgia           County
# 8           Hawaii             City
# 9            Idaho           County
# 10        Illinois            State
# 11         Indiana            State
# 12            Iowa           County
# 13          Kansas             City
# 14        Kentucky            State
# 15       Louisiana           Parish
# 16           Maine            State
# 17        Maryland            State
# 18   Massachusetts            State
# 19        Michigan            State
# 20       Minnesota             City
# 21     Mississippi           County
# 22        Missouri             City
# 23        Nebraska             City
# 24          Nevada           County
# ...

# %%
O2C_REVIEW_LEVEL['State'] = O2C_REVIEW_LEVEL['State'].map(us_states_abbreviations)
O2C_REVIEW_LEVEL
# Out:
#    State O2C Review Level
# 0     AL             City
# 1     AZ             City
# 2     AR           County
# 3     CA             City
# 4     CO             City
# 5     CT            State
# 6     FL           County
# 7     GA           County
# 8     HI             City
# 9     ID           County
# 10    IL            State
# 11    IN            State
# 12    IA           County
# 13    KS             City
# 14    KY            State
# 15    LA           Parish
# 16    ME            State
# 17    MD            State
# 18    MA            State
# 19    MI            State
# 20    MN             City
# 21    MS           County
# 22    MO             City
# 23    NE             City
# 24    NV           County
# 25    NJ            State
# 26    NM             City
# 27    NY         Bourough
# 28    NC           County
# 29    ND           County
# 30    OH            State
# 31    OK             City
# 32    PA           County
# 33    RI            State
# ...

# %%
#borra los rows que digan DC
O2C_REVIEW_LEVEL = O2C_REVIEW_LEVEL[O2C_REVIEW_LEVEL['State'] != 'DC']
O2C_REVIEW_LEVEL
# Out:
#    State O2C Review Level
# 0     AL             City
# 1     AZ             City
# 2     AR           County
# 3     CA             City
# 4     CO             City
# 5     CT            State
# 6     FL           County
# 7     GA           County
# 8     HI             City
# 9     ID           County
# 10    IL            State
# 11    IN            State
# 12    IA           County
# 13    KS             City
# 14    KY            State
# 15    LA           Parish
# 16    ME            State
# 17    MD            State
# 18    MA            State
# 19    MI            State
# 20    MN             City
# 21    MS           County
# 22    MO             City
# 23    NE             City
# 24    NV           County
# 25    NJ            State
# 26    NM             City
# 27    NY         Bourough
# 28    NC           County
# 29    ND           County
# 30    OH            State
# 31    OK             City
# 32    PA           County
# 33    RI            State
# ...

# %%
#añade un row que contenga en la columna state el valor "DC" y en la siguiente columna State
O2C_REVIEW_LEVEL.loc[len(O2C_REVIEW_LEVEL)] = ['DC', 'State']
O2C_REVIEW_LEVEL
# Out:
#    State O2C Review Level
# 0     AL             City
# 1     AZ             City
# 2     AR           County
# 3     CA             City
# 4     CO             City
# 5     CT            State
# 6     FL           County
# 7     GA           County
# 8     HI             City
# 9     ID           County
# 10    IL            State
# 11    IN            State
# 12    IA           County
# 13    KS             City
# 14    KY            State
# 15    LA           Parish
# 16    ME            State
# 17    MD            State
# 18    MA            State
# 19    MI            State
# 20    MN             City
# 21    MS           County
# 22    MO             City
# 23    NE             City
# 24    NV           County
# 25    NJ            State
# 26    NM             City
# 27    NY         Bourough
# 28    NC           County
# 29    ND           County
# 30    OH            State
# 31    OK             City
# 32    PA           County
# 33    RI            State
# ...

# %%
O2C_REVIEW_LEVEL.loc[len(O2C_REVIEW_LEVEL)] = ['AK', 'State']
O2C_REVIEW_LEVEL
# Out:
#    State O2C Review Level
# 0     AL             City
# 1     AZ             City
# 2     AR           County
# 3     CA             City
# 4     CO             City
# 5     CT            State
# 6     FL           County
# 7     GA           County
# 8     HI             City
# 9     ID           County
# 10    IL            State
# 11    IN            State
# 12    IA           County
# 13    KS             City
# 14    KY            State
# 15    LA           Parish
# 16    ME            State
# 17    MD            State
# 18    MA            State
# 19    MI            State
# 20    MN             City
# 21    MS           County
# 22    MO             City
# 23    NE             City
# 24    NV           County
# 25    NJ            State
# 26    NM             City
# 27    NY         Bourough
# 28    NC           County
# 29    ND           County
# 30    OH            State
# 31    OK             City
# 32    PA           County
# 33    RI            State
# ...

# %%
#mostrar si hay duplicados
duplicados_O2C = O2C_REVIEW_LEVEL[O2C_REVIEW_LEVEL.duplicated()]
duplicados_O2C
# Out:
# Empty DataFrame
# Columns: [State, O2C Review Level]
# Index: []

# %%
#mostrar nulos
O2C_REVIEW_LEVEL.isnull().sum()
# Out:
# State               1
# O2C Review Level    0
# dtype: int64

# %%
O2C_REVIEW_LEVEL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48 entries, 0 to 47
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             47 non-null     object
#  1   O2C Review Level  48 non-null     object
# dtypes: object(2)
# memory usage: 1.1+ KB

# %%
O2C_REVIEW_LEVEL.to_csv('O2C_REVIEW_LEVEL.csv', index=False)

# %% [markdown]
# #Ledger

# %%
Ledger_copia = Ledger.copy()

# %%
Ledger.columns
# Out:
# Index(['Journal Id', 'Region', 'Tax Location', ' Tax Level', 'Tax Authority',
#        'Tax Type', 'Tax Name', 'Gross', 'Exemptions', 'Taxable', 'Rate', 'Tax',
#        'Tax Collected', 'Over(Under) Collected', 'Charge Name', 'Quantity',
#        'Charge Rate', 'Charge', 'Credit Name', 'Credit', 'Calc', 'Invoice #',
#        'Item #', 'Business Location', 'Tax Area Code', 'County', 'City',
#        'Districts', 'Collecting Level', 'Collecting Authority', 'Tax Code',
#        'Department Code', 'Vendor Number', ' Customer Number', 'Description '],
#       dtype='object')

# %%
Ledger_final = Ledger[['Region',' Tax Level','County', 'City','Tax Collected']]
Ledger_final.head()
# Out:
#   Region  Tax Level  County    City  Tax Collected
# 0  US-GA     COUNTY   BACON    ALMA         0.0000
# 1  US-GA     COUNTY   BACON    ALMA       330.9375
# 2  US-GA     COUNTY   BACON    ALMA         0.0000
# 3  US-GA     COUNTY   BACON    ALMA         0.0000
# 4  US-GA     COUNTY  BARROW  AUBURN         8.3800

# %%
Ledger_final['Region'] = Ledger_final['Region'].str.replace('US-', '')
Ledger_final.head()
# Out:
# <ipython-input-137-b22c273530bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ledger_final['Region'] = Ledger_final['Region'].str.replace('US-', '')
#   Region  Tax Level  County    City  Tax Collected
# 0     GA     COUNTY   BACON    ALMA         0.0000
# 1     GA     COUNTY   BACON    ALMA       330.9375
# 2     GA     COUNTY   BACON    ALMA         0.0000
# 3     GA     COUNTY   BACON    ALMA         0.0000
# 4     GA     COUNTY  BARROW  AUBURN         8.3800

# %%
#poner solo mayusculas y eliminar espacios de tax level
Ledger_final[' Tax Level'] = Ledger_final[' Tax Level'].str.title().str.strip()
Ledger_final.head()
# Out:
# <ipython-input-138-e7b8e4e4d8d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ledger_final[' Tax Level'] = Ledger_final[' Tax Level'].str.title().str.strip()
#   Region  Tax Level  County    City  Tax Collected
# 0     GA     County   BACON    ALMA         0.0000
# 1     GA     County   BACON    ALMA       330.9375
# 2     GA     County   BACON    ALMA         0.0000
# 3     GA     County   BACON    ALMA         0.0000
# 4     GA     County  BARROW  AUBURN         8.3800

# %%
Ledger_final['Region'] = Ledger_final['Region'].str.strip()
Ledger_final['County'] = Ledger_final['County'].str.strip().str.title()
Ledger_final['City'] = Ledger_final['City'].str.strip().str.title()
Ledger_final
# Out:
# <ipython-input-139-1e49ebe5973d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ledger_final['Region'] = Ledger_final['Region'].str.strip()
# <ipython-input-139-1e49ebe5973d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ledger_final['County'] = Ledger_final['County'].str.strip().str.title()
# <ipython-input-139-1e49ebe5973d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
Ledger_final['Region'].value_counts()
# Out:
# Region
# TX    15123
# CA    12620
# FL     5957
# VA     4355
# MN     4229
# IL     4078
# AL     4047
# NY     3895
# NC     3520
# TN     3488
# AZ     3485
# OH     3295
# GA     3203
# UT     2772
# MO     2071
# OK     1985
# KS     1976
# NE     1804
# MI     1763
# SC     1717
# IA     1651
# WI     1533
# WA     1165
# MA     1134
# MD     1121
# PA     1111
# IN      991
# NM      782
# LA      744
# NV      728
# NJ      700
# KY      690
# MS      632
# ND      533
# CT      340
# SD      305
# ID      260
# VT      170
# ME      165
# HI      164
# WV      153
# RI       87
# WY       82
# DC       24
# AK        6
# Name: count, dtype: int64

# %%
#Busca los rows que la región sea DC
Ledger_final[Ledger_final['Region'] == 'AK']
# Out:
#       Region  Tax Level     County       City  Tax Collected
# 18656     AK      State  Anchorage  Anchorage            0.0
# 18657     AK      State  Anchorage  Anchorage            0.0
# 18658     AK      State  Anchorage  Anchorage            0.0
# 18659     AK      State  Anchorage  Anchorage            0.0
# 18660     AK      State  Anchorage  Anchorage            0.0
# 18661     AK      State  Anchorage  Anchorage            0.0

# %%
Ledger_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100654 entries, 0 to 100653
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Region         100654 non-null  object
#  1    Tax Level     100654 non-null  object
#  2   County         100654 non-null  object
#  3   City           100654 non-null  object
#  4   Tax Collected  100654 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 3.8+ MB

# %%
#crea una función que cuenta el número máximo de carácteres de un dataframe
def get_max_lengths(df):
    max_lengths = df.applymap(lambda x: len(str(x))).max()
    return max_lengths

get_max_lengths(Negativos_final)
# Out:
# <ipython-input-143-6a4e88f72492>:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   max_lengths = df.applymap(lambda x: len(str(x))).max()
# Return Period Used                              3
# Expiration Date - Please extend the formula    19
# Document Number                                10
# Data Source                                     9
# Taxable State                                   2
# Taxable County                                 12
# Taxable City                                   20
# State Tax Amount                                9
# County Tax Amount                               8
# City Tax Amount                                 8
# Total Tax Amount                                9
# fuente                                          9
# dtype: int64

# %%
#Tabla dinamica de Ledger donde las filas se agrupan por Region, County y City, las columnas se definen por Tax Level y los valores son la sumatoria de Tax Collected
tabla_comparacion = Ledger_final.pivot_table(index=['Region','County','City'], columns=' Tax Level', values='Tax Collected', aggfunc='sum')
tabla_comparacion
# Out:
#  Tax Level                                 City       County  District  \
# Region County    City
# AK     Anchorage Anchorage                  NaN          NaN       NaN
# AL     Baldwin   Daphne                   0.000     0.000000       NaN
#                  Foley                  425.778   425.778000       NaN
#                  Orange Beach          1235.988  1235.988000       NaN
#        Barbour   Eufaula                  0.000     0.000000       NaN
# ...                                         ...          ...       ...
# WY     Fremont   Riverton                   NaN     0.000000       NaN
#        Laramie   Cheyenne                   NaN     0.000000       NaN
#                  Unincorporated Areas       NaN     0.000000       NaN
#        Natrona   Casper                     NaN     0.000000       NaN
#        Teton     Unincorporated Areas       NaN   970.666667       NaN
#
#  Tax Level                                   State
# Region County    City
# ...

# %%
Ledger_final.to_csv('Ledger_Final.csv', index=False)
